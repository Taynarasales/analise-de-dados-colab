# %% [markdown]
# <a href="https://colab.research.google.com/github/Taynarasales/Taynarasales/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "taynara";
print(f"ola", nome)
# Out:
# ola taynara

# %%
nome="taynara"
idade= 23
cidade= "hortolandia"

print(f"Qual seu nome? {nome}, qual sua idade? {idade}, qual sua cidade? {cidade}")
# Out:
# Qual seu nome? taynara, qual sua idade? 23, qual sua cidade? hortolandia

# %%
# variaveis globais do sistema
alunos = ["Rafeal","Jessica","Erick","Taynara","Rafael P"]

# exibibir os dados da lista
print(alunos)
# exibir um item da lista - chama a lista e seu index  list[index]
print(alunos[-1])
# os index sao as posições dos elementos
# começando em 0 e indo ao infinito
# importante, podemos usar os valor -1 para ultimo
# -2 para penultimo
# -3 antepenultimo e assim por diante
# Out:
# ['Rafeal', 'Jessica', 'Erick', 'Taynara', 'Rafael P']
# Rafael P
